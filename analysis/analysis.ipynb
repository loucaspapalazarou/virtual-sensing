# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("version_2.csv")

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(df["Step"], df["Value"])
plt.title("Value over Steps")
plt.xlabel("Step")
plt.ylabel("Value")
plt.grid(True)
plt.show()
